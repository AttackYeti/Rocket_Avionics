# %%
import matplotlib.pyplot as plt
import pandas as pd, numpy as np
from scipy.optimize import curve_fit

# %%
path = "./low_pressure_sensor_charactarization.csv"

data = pd.read_csv(path)

# %%
print(data.columns)
# Out:
# Index(['raw', 'actual'], dtype='object')

# %%
plt.plot(data['raw'], data['actual'])

# %%
def lin(x, a, b):
    return a*x +b

pars, conv = curve_fit(lin, data.raw, data.actual)
print("{}*x + {}".format(pars[0], pars[1]))
# Out:
# 1.2258857538273733*x + -123.89876445934394

# %%
highPressuredata = "./Ball_Valve_Characterization/high_pressure_sensor.txt"

highData = pd.read_csv(highPressuredata)
print(highData.columns)
# Out:
# Index(['raw', 'actual(psi)'], dtype='object')

# %%
plt.plot(highData['raw'], highData['actual(psi)'])

# %%
highPars, highCov = curve_fit(lin, highData.raw, highData['actual(psi)'])
print("{}*raw + {}".format(highPars[0], highPars[1]))
# Out:
# 6.612739309669555*raw + -1237.7612969223858
